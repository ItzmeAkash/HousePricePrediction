# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #**Prepareing the Dataset**

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Self Projects/Ml/Boston Housing Price Prediction/HousingData.csv')

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# Summarizing the stats of the data
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#Check the missing values
dataset.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# # **Exploratory Data Analyis**

# %% [markdown]
# ### **1.Correlation**

# %%
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.188075  0.391552 -0.051970  0.416160 -0.227170  0.341311
# ZN      -0.188075  1.000000 -0.521256 -0.033357 -0.515660  0.343210 -0.568174
# INDUS    0.391552 -0.521256  1.000000  0.049820  0.762737 -0.403068  0.642387
# CHAS    -0.051970 -0.033357  0.049820  1.000000  0.076661  0.095308  0.072644
# NOX      0.416160 -0.515660  0.762737  0.076661  1.000000 -0.316563  0.732540
# RM      -0.227170  0.343210 -0.403068  0.095308 -0.316563  1.000000 -0.248670
# AGE      0.341311 -0.568174  0.642387  0.072644  0.732540 -0.248670  1.000000
# DIS     -0.365052  0.645359 -0.696569 -0.095037 -0.768137  0.218713 -0.753547
# RAD      0.608667 -0.298773  0.591944  0.014102  0.628170 -0.236057  0.443585
# TAX      0.560841 -0.305768  0.734204 -0.026513  0.679824 -0.320561  0.504472
# PTRATIO  0.265428 -0.422164  0.395691 -0.104995  0.210216 -0.390686  0.264968
# ...

# %%
plt.scatter(dataset['CRIM'],dataset['MEDV'])
plt.xlabel('Crime Rate')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %%
plt.scatter(dataset['RM'],dataset['MEDV'])
plt.xlabel('RM')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %%
sns.regplot(x='RM',y='MEDV',data=dataset)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %%
sns.regplot(x='CHAS',y='MEDV',data=dataset)
# Out:
# <Axes: xlabel='CHAS', ylabel='MEDV'>

# %%
sns.regplot(x='PTRATIO',y='MEDV',data=dataset)
# Out:
# <Axes: xlabel='PTRATIO', ylabel='MEDV'>

# %% [markdown]
# ### **Train Test Split**

# %%
# Independent and dependent features

X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 5  394.12   5.21

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 5      28.7
#        ...
# 499    17.5
# 500    16.8
# 502    20.6
# 503    23.9
# 504    22.0
# Name: MEDV, Length: 394, dtype: float64

# %%
##Train Test Split
from sklearn.model_selection import train_test_split\

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#          CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 21    0.85204  0.0   8.14   0.0  0.538  5.965  89.2  4.0123    4  307
# 456   4.66883  0.0  18.10   0.0  0.713  5.976  87.9  2.5806   24  666
# 28    0.77299  0.0   8.14   0.0  0.538  6.495  94.4  4.4547    4  307
# 156   2.44668  0.0  19.58   0.0  0.871  5.272  94.0  1.7364    5  403
# 445  10.67180  0.0  18.10   0.0  0.740  6.459  94.8  1.9879   24  666
# ..        ...  ...    ...   ...    ...    ...   ...     ...  ...  ...
# 84    0.05059  0.0   4.49   0.0  0.449  6.389  48.0  4.7794    3  247
# 128   0.32543  0.0  21.89   0.0  0.624  6.431  98.8  1.8125    4  437
# 345   0.03113  0.0   4.39   0.0  0.442  6.014  48.5  8.0136    3  352
# 448   9.32909  0.0  18.10   0.0  0.713  6.185  98.7  2.2616   24  666
# 122   0.09299  0.0  25.65   0.0  0.581  5.961  92.9  2.0869    2  188
#
#      PTRATIO       B  LSTAT
# 21      21.0  392.53  13.83
# 456     20.2   10.48  19.01
# 28      21.0  387.94  12.80
# ...

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE      DIS  RAD  TAX  \
# 93   0.02875  28.0  15.04   0.0  0.464  6.211  28.9   3.6659    4  270
# 352  0.07244  60.0   1.69   0.0  0.411  5.884  18.5  10.7103    4  411
# 319  0.47547   0.0   9.90   0.0  0.544  6.113  58.8   4.0019    4  304
# 65   0.03584  80.0   3.37   0.0  0.398  6.290  17.8   6.6115    4  337
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5   2.3999    6  391
# ..       ...   ...    ...   ...    ...    ...   ...      ...  ...  ...
# 358  5.20177   0.0  18.10   1.0  0.770  6.127  83.4   2.7227   24  666
# 457  8.20058   0.0  18.10   0.0  0.713  5.936  80.3   2.7792   24  666
# 321  0.18159   0.0   7.38   0.0  0.493  6.376  54.3   4.5404    5  287
# 190  0.09068  45.0   3.44   0.0  0.437  6.951  21.5   6.4798    5  398
# 131  1.19294   0.0  21.89   0.0  0.624  6.326  97.7   2.2710    4  437
#
#      PTRATIO       B  LSTAT
# 93      18.2  396.33   6.21
# 352     18.3  392.33   7.79
# ...

# %%
##Standardize the dataset

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test )

# %% [markdown]
# ###**Model Training**

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
##Print the coefficients and intercept

print(regression.coef_)
print(regression.intercept_)
# Out:
# [-1.16422484  1.06108499  0.39032387  0.29209079 -1.99660097  2.919107
#  -0.56678274 -2.98589329  2.41887408 -2.87948075 -1.92242361  0.87551786
#  -2.71551439]
# 21.872363636363634

# %%
# On which parameters the model has been trained
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
# Prediction with Test data

reg_predict=regression.predict(X_test)
reg_predict
# Out:
# array([29.48758967, 16.89843072, 21.88395113, 30.03140416, 18.33998157,
#        34.41717332, 22.29567579, 30.18541478, 32.68800811, 15.15148614,
#        22.00937236, 40.89756783, 21.39760824, 16.631487  , 18.56021823,
#        20.16135634, 17.03230083, 15.23458095, 22.21007405, 14.03864948,
#        18.38308584, 20.31978106, 16.70540425, 29.04732153, 25.84896274,
#        16.21750987, 26.91521769, 31.48625718, 23.80195772, 26.88649048,
#        40.79205858, 17.93939578, 21.74000234, 17.0218407 , 17.45215081,
#        20.87478891, 22.15708989, 21.38558618, 23.05850448, 21.06608939,
#        27.72449001, 34.81400202, 21.78651421, 30.44288708, 34.59722541,
#        19.75813031, 24.68728038, 10.22457273, 19.81849411, 25.15817576,
#        21.82205121, 25.58520471, 14.76531893, 18.31754995, 18.17045495,
#        23.96198129, 43.37418034, 22.39050206, 15.68056608, 23.22677962,
#        20.98939499, 21.55059106, 14.59407927, 28.87042011, -3.45096729,
# ...

# %% [markdown]
# ### **Assumption**

# %%
# plot a scatter plot for the prediction
plt.scatter(y_test,reg_predict)

# %%
residuals=y_test-reg_predict

# %%
residuals
# Out:
# 93    -4.487590
# 352    1.701569
# 319   -0.883951
# 65    -6.531404
# 499   -0.839982
#          ...
# 358    3.929978
# 457    1.646164
# 321   -1.638334
# 190    6.555052
# 131    0.491326
# Name: MEDV, Length: 119, dtype: float64

# %%
# plot this residual

sns.displot(residuals,kind='kde')

# %%
# Scatter plot with respect to prediction and residuals
# Unifrom distribution
plt.scatter(reg_predict,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_predict))
print(mean_squared_error(y_test,reg_predict))
print(np.sqrt(mean_squared_error(y_test,reg_predict)))
# Out:
# 3.4558210072479936
# 28.870771928253443
# 5.373152885248422

# %% [markdown]
# ### **R square and adjusted R square**

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_predict)
print(score)
# Out:
# 0.6905175764205996

# %%
# display adjusted R squre

# adj_r2=1-[(1-r2)*(n-1)/n-k-1]


adjusted_R_squre=1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)

# adjusted r squre is less than r square this propertites is need to happend so it is current

print(adjusted_R_squre)
# Out:
# 0.6522007049298166

# %% [markdown]
# ### **New Predication**

# %%
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 5    0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69   0.0  0.585  6.027  79.7  2.4982    6  391
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
bostondata=dataset.iloc[:,:-1].values

# %%
bostondata[0].reshape(1,-1).shape
# Out:
# (1, 13)

# %%
regression.predict(bostondata[0].reshape(1,-1))
# Out:
# array([-534.53212793])

# %% [markdown]
# In this we get -ve point beacause of we didn't apply the strandrization so we have to apply the strandrization

# %%
# Transfromation of new data
scaler.transform(bostondata[0].reshape(1,-1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.40933976,  0.27402606, -1.27968808, -0.26464865, -0.14934433,
#          0.45085129, -0.13851441,  0.13589148, -0.99766233, -0.64963388,
#         -1.52711029,  0.44817157, -1.07231454]])

# %%
regression.predict(scaler.transform(bostondata[0].reshape(1,-1)))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([29.04732153])

# %% [markdown]
# ### **Pickling The model File for Deployment**

# %%
import pickle

# %%
#Convert this into a pickle file use dump

pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pickle.load(open('/content/drive/MyDrive/Self Projects/Ml/Boston Housing Price Prediction/regmodel.pkl','rb'))

# %%
pickled_model.predict(scaler.transform(bostondata[0].reshape(1,-1)))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([29.04732153])
